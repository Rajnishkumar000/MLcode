# %% [markdown]
# # **Data Augmentation**
# #
# Having more data (dataset / samples) is a best way to get better consistent estimators (ML model)
#
# Data Augmentation is one of the interesting regularization technique to resolve Overfitting. The concept is very simple, this technique generates new training data from given original dataset. Dataset Augmentation provides a cheap and easy way to increase the amount of your training data.
#
# This technique can be used for both NLP and CV.

# %% [markdown]
# It is worth knowing that Keras’ provided ImageDataGenerator for generating Data Augmentation.
#
# > tf.keras.preprocessing.image_dataset_from_directory

# %% [markdown]
# > tf.keras.preprocessing.image.ImageDataGenerator(
#     rotation_range=0, width_shift_range=0.0,
#     height_shift_range=0.0, brightness_range=None, shear_range=0.0, zoom_range=0.0,
# fill_mode='nearest', cval=0.0, horizontal_flip=False,
#     vertical_flip=False, rescale=None, validation_split=0.0
# )

# %% [markdown]
# 1) **rotation_range** : Int. Degree range for random rotations.
#
# (2) **width_shift_range** : Float, 1-D array-like or int
#
# (3) **height_shift_range** : Float, 1-D array-like or int
#
# shift to an image means moving all pixels of the image in one direction, such as horizontally or vertically, while keeping the image dimensions the same
#
# (4) **brightness_range** : Tuple or list of two floats. Range for picking a brightness shift value from
#
# (5) **shear_range** : Float. Shear Intensity
#
# (6) **zoom_range** : Float or [lower, upper]. Range for random zoom
#
# (7) **fill_mode** :One of {"constant", "nearest", "reflect" or "wrap"}. Default is 'nearest'. Points outside the boundaries of the input are filled according to the given mode:.
#
# (8) **horizontal_flip** :Boolean. Randomly flip inputs horizontally.
#
# **(9) vertical_flip** : Boolean. Randomly flip inputs vertically.
#
# (10) **cval Float or Int**. Value used for points outside the boundaries when fill_mode = "constant".
#
# (11) **validation_split** Float. Fraction of images reserved for validation (strictly between 0 and 1).
#
# (12) **rescale rescaling factor**. Defaults to None. If None or 0, no rescaling is applied, otherwise we multiply the data by the value provided rescale parameter multiplies the data with a scalar, usually we use 1/255. This makes the mean of the data at 0.5 with range 0. to 1

# %%
from  matplotlib import pyplot
from keras.preprocessing.image import load_img
img = load_img('C:/Users/Rajnish/OneDrive/Desktop/bird.jpg')
pyplot.imshow(img)

# %% [markdown]
# # zoom_range

# %%
from keras.src.legacy.preprocessing.image import ImageDataGenerator
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from matplotlib import pyplot
# load the image
img = load_img('C:/Users/Rajnish/OneDrive/Desktop/bird.jpg')
# convert to numpy array
data = img_to_array(img)

samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(zoom_range=0.2,fill_mode="wrap")
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 21
#      19 pyplot.subplot(330 + 1 + i)
#      20 # generate batch of images
# ---> 21 batch = it.next()
#      22 # convert to unsigned integers for viewing
#      23 image = batch[0].astype('uint8')
#
# AttributeError: 'NumpyArrayIterator' object has no attribute 'next'

# %%
datagen = ImageDataGenerator(height_shift_range=[-200,200])
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # rotation_range

# %%
datagen = ImageDataGenerator(rotation_range= 80)
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # height_shift_range

# %%
datagen = ImageDataGenerator(height_shift_range=[-200,200])
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # horizontal_flip

# %%
datagen = ImageDataGenerator(horizontal_flip=True)
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # brightness_range

# %%
datagen = ImageDataGenerator(brightness_range=[0.2,1.0])
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # vertical_flip

# %%
datagen = ImageDataGenerator(vertical_flip=True)
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# # shear_range

# %%
datagen = ImageDataGenerator(shear_range=0.6)
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# #  If you like this Notebook
# #  please Vote and comment ,thanks
